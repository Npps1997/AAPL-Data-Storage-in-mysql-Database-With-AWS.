# %%
#Importing necessary Libraries

import yfinance as yf
import pandas as pd

# %%
aapl = yf.Ticker('AAPL')

# %%
print(aapl.info)
# Out:
# {'zip': '95014', 'sector': 'Technology', 'fullTimeEmployees': 164000, 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. In addition, the company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. Further, it provides AppleCare support and cloud services store services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. Additionally, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radi
# ...

# %%
#Downloading AAPL stock data from yahoo finance and creating dataframe

df = yf.download("AAPL", start="2012-10-30")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
df.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2012-10-31  21.245714  21.498571  20.989286  21.261429  18.231628  510003200
# 2012-11-01  21.365000  21.535713  21.220358  21.305000  18.268993  361298000
# 2012-11-02  21.281786  21.319643  20.526787  20.600000  17.664457  599373600
# 2012-11-05  20.840000  20.991785  20.628571  20.879286  17.903934  529135600
# 2012-11-06  21.079643  21.097857  20.717501  20.816071  17.849737  374917200

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-10-26  150.960007  151.990005  148.039993  149.350006  149.350006
# 2022-10-27  148.070007  149.050003  144.130005  144.800003  144.800003
# 2022-10-28  148.199997  157.500000  147.820007  155.740005  155.740005
# 2022-10-31  153.160004  154.240005  151.919998  153.339996  153.339996
# 2022-11-01  155.080002  155.449997  149.130005  150.649994  150.649994
#
#                Volume
# Date
# 2022-10-26   88194300
# 2022-10-27  109180200
# 2022-10-28  164762400
# 2022-10-31   97943200
# 2022-11-01   80321400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2519 entries, 2012-10-31 to 2022-11-01
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2519 non-null   float64
#  1   High       2519 non-null   float64
#  2   Low        2519 non-null   float64
#  3   Close      2519 non-null   float64
#  4   Adj Close  2519 non-null   float64
#  5   Volume     2519 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 137.8 KB

# %%
df.shape
# Out:
# (2519, 6)

# %%
df = df.reset_index().rename({'Date':'Time_Stamp'}, axis = 'columns')
df
# Out:
#      Time_Stamp        Open        High         Low       Close   Adj Close  \
# 0    2012-10-31   21.245714   21.498571   20.989286   21.261429   18.231628
# 1    2012-11-01   21.365000   21.535713   21.220358   21.305000   18.268993
# 2    2012-11-02   21.281786   21.319643   20.526787   20.600000   17.664457
# 3    2012-11-05   20.840000   20.991785   20.628571   20.879286   17.903934
# 4    2012-11-06   21.079643   21.097857   20.717501   20.816071   17.849737
# ...         ...         ...         ...         ...         ...         ...
# 2514 2022-10-26  150.960007  151.990005  148.039993  149.350006  149.350006
# 2515 2022-10-27  148.070007  149.050003  144.130005  144.800003  144.800003
# 2516 2022-10-28  148.199997  157.500000  147.820007  155.740005  155.740005
# 2517 2022-10-31  153.160004  154.240005  151.919998  153.339996  153.339996
# 2518 2022-11-01  155.080002  155.449997  149.130005  150.649994  150.649994
#
#          Volume
# 0     510003200
# 1     361298000
# ...

# %%
df.insert(0, 'id', range(1, 1 + len(df)))

# %%
df
# Out:
#         id Time_Stamp        Open        High         Low       Close  \
# 0        1 2012-10-31   21.245714   21.498571   20.989286   21.261429
# 1        2 2012-11-01   21.365000   21.535713   21.220358   21.305000
# 2        3 2012-11-02   21.281786   21.319643   20.526787   20.600000
# 3        4 2012-11-05   20.840000   20.991785   20.628571   20.879286
# 4        5 2012-11-06   21.079643   21.097857   20.717501   20.816071
# ...    ...        ...         ...         ...         ...         ...
# 2514  2515 2022-10-26  150.960007  151.990005  148.039993  149.350006
# 2515  2516 2022-10-27  148.070007  149.050003  144.130005  144.800003
# 2516  2517 2022-10-28  148.199997  157.500000  147.820007  155.740005
# 2517  2518 2022-10-31  153.160004  154.240005  151.919998  153.339996
# 2518  2519 2022-11-01  155.080002  155.449997  149.130005  150.649994
#
#        Adj Close     Volume
# 0      18.231628  510003200
# 1      18.268993  361298000
# 2      17.664457  599373600
# ...

# %%
# !pip install mysql-connector

# %%
import mysql.connector as SQLC
# Establishing connection with the SQL
 
DataBase = SQLC.connect(
  host ="ROOT",
  user ="USERNAME",
  password ="PASSWORD"
)
# Cursor to the database
Cursor = DataBase.cursor()
 
Cursor.execute("CREATE DATABASE InternAssignment")
print("Database is created")
# Out:
# Database is created

# %%
Cursor.execute("use InternAssignment")

TableName ='''CREATE TABLE AAPL
                (
                    ID VARCHAR(255),
                    Time_Stamp DATE,
                    Open FLOAT,
                    High FLOAT,
                    Low FLOAT,
                    Close FLOAT,
                    Adj_CLose FLOAT,
                    Volume INT
                )'''
    
Cursor.execute(TableName)
print("AAPL Table is Created in the Database")
# Out:
# AAPL Table is Created in the Database

# %%
# !pip install PyMySQL

# %%
# Import dataframe into MySQL ie. Storing Apple Data in the AAPL table.
import pymysql
pymysql.install_as_MySQLdb()
import sqlalchemy
database_username = 'ENTER USERNAME'
database_password = 'ENTER USERNAME PASSWORD'
database_ip       = 'ROOT'
database_name     = 'InternAssignment'
database_connection = sqlalchemy.create_engine('mysql://USERNAME:PASSWORD@ROOT/InternAssignment'.
                                               format(database_username, database_password, 
                                                      database_ip, database_name))

# %%
df.to_sql(con=database_connection, name='AAPL', if_exists='replace')
# Out:
# 2519

# %%
#EveryDay when we run the code, it will update the records by adding new records.
